# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("greenbuildings.csv")
df.head()
# Out:
#    CS_PropertyID  cluster    size  empl_gr   Rent  leasing_rate  stories  age  \
# 0         379105        1  260300     2.22  38.56         91.39       14   16
# 1         122151        1   67861     2.22  28.57         87.14        5   27
# 2         379839        1  164848     2.22  33.31         88.94       13   36
# 3          94614        1   93372     2.22  35.00         97.04       13   46
# 4         379285        1  174307     2.22  40.69         96.58       16    5
#
#    renovated  class_a  ...  green_rating  net  amenities  cd_total_07  \
# 0          0        1  ...             1    0          1         4988
# 1          0        0  ...             0    0          1         4988
# 2          1        0  ...             0    0          1         4988
# 3          1        0  ...             0    0          0         4988
# 4          0        1  ...             0    0          1         4988
#
#    hd_total07  total_dd_07  Precipitation  Gas_Costs  Electricity_Costs  \
# ...

# %%
#check for missing values
missing_values = df.isnull().sum()
print("\nMissing values:\n", missing_values)
# Out:
# Missing values:
#  CS_PropertyID         0
# cluster               0
# size                  0
# empl_gr              74
# Rent                  0
# leasing_rate          0
# stories               0
# age                   0
# renovated             0
# class_a               0
# class_b               0
# LEED                  0
# Energystar            0
# green_rating          0
# net                   0
# amenities             0
# cd_total_07           0
# hd_total07            0
# total_dd_07           0
# Precipitation         0
# Gas_Costs             0
# Electricity_Costs     0
# cluster_rent          0
# dtype: int64

# %% [markdown]
# The process described by the Excel guru is a good starting point for analyzing the potential economic impact of building a green-certified project. However, there are some shortcomings and areas for improvement that should be addressed for a more comprehensive and accurate analysis. Here's how you could approach the analysis differently:
#
# 1. Exclusion of Low-Occupancy Buildings:
# While excluding low-occupancy buildings may help remove potential outliers, it's important to thoroughly investigate the reasons behind low occupancy. Low occupancy could be due to various factors unrelated to the impact of green certification, such as market conditions, location, or building management. Before excluding these buildings, a more in-depth analysis is needed to determine if their exclusion is justified.
#
# 2. Median vs. Mean Rent Calculation:
# Using the median rent is a good choice to mitigate the influence of outliers, but it might not capture the full distribution of rent premiums. Consider using other descriptive statistics (e.g., percentiles) to better understand the spread of the data and the potential variability in rent premiums.
#
# 3. Limited Consideration of Costs and Benefits:
# The analysis focuses solely on potential rent premiums as additional revenue without factoring in other costs and benefits. Consideration of operational savings, potential tax incentives, and long-term sustainability benefits of green buildings should also be included in the analysis.
#
# 4. Simplified Payback Calculation:
# The payback period calculation assumes a constant revenue increase over time and does not account for factors such as inflation, changing market conditions, or changes in operating costs. A more sophisticated financial model that considers these factors would provide a more accurate estimation of payback time.
#
# 5. Sensitivity Analysis:
# The analysis does not explore the sensitivity of the results to changes in key assumptions, such as rent premiums, construction costs, or occupancy rates. Conducting sensitivity analysis helps identify how robust the conclusions are under different scenarios.
#
# 6. Potential Confounding Variables:
# The analysis does not address potential confounding variables that might influence both green certification and rent premiums. Exploring and adjusting for confounders (e.g., building class) can lead to more accurate conclusions.
#
# 7. Risk Assessment:
# The analysis does not consider potential risks or uncertainties associated with building a green-certified project, such as regulatory changes, shifts in tenant preferences, or unexpected costs.
#
# 8. Visualizations and Data Presentation:
# The analysis could benefit from visualizations to help convey the data's distribution, relationships, and key findings more effectively.
#
# To approach the analysis differently, you should:
#
# Conduct a more thorough investigation of low-occupancy buildings before excluding them.
# Use a variety of descriptive statistics to analyze rent premiums.
# Consider a more comprehensive assessment of costs and benefits.
# Develop a more sophisticated financial model that accounts for time value of money and other relevant financial concepts.
# Perform sensitivity analysis to assess the impact of key assumptions.
# Adjust for potential confounding variables.
# Conduct a risk assessment to identify and mitigate potential risks.
# Utilize visualizations to present data and findings in a clear and understandable manner.
# By addressing these shortcomings and approaching the analysis more comprehensively, you can provide the developer with a more accurate and informed recommendation regarding the financial feasibility of building a green-certified project.

# %%
# Example: Scatter plot between size and rent
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='size', y='Rent', hue='green_rating')
plt.title("Size vs. Rent by Green Rating")
plt.xlabel("Size")
plt.ylabel("Rent")
plt.legend()
plt.show()

# %%
# Calculate correlation matrix
correlation_matrix = df.corr()

# Visualize correlation matrix using a heatmap
plt.figure(figsize=(20, 20))
sns.heatmap(data=df, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()
